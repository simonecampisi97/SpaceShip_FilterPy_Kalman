# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import animation
from matplotlib.animation import FuncAnimation, PillowWriter
import os
from IPython.display import Image


from kalman_utils_9x9 import *
from model_evaluation_9x9 import plot_residuals

from filterpy.kalman import KalmanFilter
from filterpy.common import Q_discrete_white_noise
from scipy.linalg import block_diag
from filterpy.stats import plot_covariance_ellipse
from filterpy.common import Saver

# %% [markdown]
# ## Adding noise to the Position

# %%
traj = Trajectoy3DGenerattion()

# %%
fig = plt.figure(figsize=(16,9))
ax = fig.add_subplot(111, projection='3d')
ax.set_title("Noisy Measurements")

plot_measurements_3D(traj, ax)

# %%
tracker = Ship_tracker(traj)

preds, cov = run(tracker, traj)

# %%
plot_prediction(preds, traj)
